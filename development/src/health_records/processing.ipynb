# %% [markdown]
# # Processing

# %%
# import libraries

import math
import random

import pandas as pd

# %%
# data folder

data_folder = '../../data/health_records'

# %%
# load electronic health records data

patients = pd.read_csv(f"{data_folder}/patients.csv")

allergies = pd.read_csv(f"{data_folder}/allergies.csv")
careplans = pd.read_csv(f"{data_folder}/careplans.csv")
conditions = pd.read_csv(f"{data_folder}/conditions.csv")
devices = pd.read_csv(f"{data_folder}/devices.csv")
encounters = pd.read_csv(f"{data_folder}/encounters.csv")
imagings = pd.read_csv(f"{data_folder}/imagings.csv")
immunizations = pd.read_csv(f"{data_folder}/immunizations.csv")
medications = pd.read_csv(f"{data_folder}/medications.csv")
observations = pd.read_csv(f"{data_folder}/observations.csv")
procedures = pd.read_csv(f"{data_folder}/procedures.csv")

# %%
def clean_nans(obj : dict | list | float) -> dict | list | str:
    '''
    Replaces all NaN values with an empty string
    '''
    if isinstance(obj, dict):
        return {k: clean_nans(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [clean_nans(item) for item in obj]
    elif isinstance(obj, float) and math.isnan(obj):
        return ''
    else:
        return obj

# %%
def get_health_records(patient_id : str) -> dict:
    '''
    Gather all health records for a given patient
    '''
    health_record = {}
    health_record['patient'] = patients[patients['Id'] == patient_id][['Id', 'BIRTHDATE', 'MARITAL', 'RACE', 'ETHNICITY', 'GENDER']]\
        .to_dict(orient='records')[0]
    health_record['allergies'] = allergies[allergies['PATIENT'] == patient_id]['DESCRIPTION'].tolist()
    health_record['careplans'] = careplans[careplans['PATIENT'] == patient_id]['DESCRIPTION'].tolist()
    health_record['conditions'] = conditions[conditions['PATIENT'] == patient_id]['DESCRIPTION'].tolist()
    health_record['devices'] = devices[devices['PATIENT'] == patient_id]['DESCRIPTION'].tolist()
    health_record['encounters'] = encounters[encounters['PATIENT'] == patient_id]['DESCRIPTION'].tolist()
    health_record['imagings'] = imagings[imagings['PATIENT'] == patient_id][['BODYSITE_DESCRIPTION', 'MODALITY_DESCRIPTION']]\
        .values.tolist()
    health_record['immunizations'] = immunizations[immunizations['PATIENT'] == patient_id]['DESCRIPTION'].tolist()
    health_record['medications'] = medications[medications['PATIENT'] == patient_id]['DESCRIPTION'].tolist()
    health_record['observations'] = observations[observations['PATIENT'] == patient_id][['DESCRIPTION', 'VALUE', 'UNITS']]\
        .values.tolist()
    health_record['procedures'] = procedures[procedures['PATIENT'] == patient_id]['DESCRIPTION'].tolist()
    return clean_nans(health_record)

# %%
def display_health_records(health_records : dict):
    '''
    Displays all health records for a given patient
    '''
    print('-' * 100)
    print('Patient:')
    print(f" - ID: {health_records['patient']['Id']}")
    print(f" - BIRTHDATE: {health_records['patient']['BIRTHDATE']}")
    print(f" - MARITAL: {health_records['patient']['MARITAL']}")
    print(f" - RACE: {health_records['patient']['RACE']}")
    print(f" - ETHNICITY: {health_records['patient']['ETHNICITY']}")
    print(f" - GENDER: {health_records['patient']['GENDER']}")
    print('-' * 100)
    print('Allergies:')
    for allergy in health_records['allergies']:
        print(f' - {allergy}')
    print('-' * 100)
    print('Careplans:')
    for careplan in health_records['careplans']:
        print(f' - {careplan}')
    print('-' * 100)
    print('Conditions:')
    for condition in health_records['conditions']:
        print(f' - {condition}')
    print('-' * 100)
    print('Devices:')
    for device in health_records['devices']:
        print(f' - {device}')
    print('-' * 100)
    print('Encounters:')
    for encounter in health_records['encounters']:
        print(f' - {encounter}')
    print('-' * 100)
    print('Imagings:')
    for imaging in health_records['imagings']:
        print(f' - {imaging[0]} ({imaging[1]})')
    print('-' * 100)
    print('Immunizations:')
    for immunization in health_records['immunizations']:
        print(f' - {immunization}')
    print('-' * 100)
    print('Medications:')
    for medication in health_records['medications']:
        print(f' - {medication}')
    print('-' * 100)
    print('Observations:')
    for observation in health_records['observations']:
        print(f' - {observation[0]}: {observation[1]} {observation[2]}')
    print('-' * 100)
    print('Procedures:')
    for procedure in health_records['procedures']:
        print(f' - {procedure}')
    print('-' * 100)

# %%
# get electronic health records for a random patient

patient_id = random.choice(patients['Id'].values)
health_records = get_health_records(patient_id)
display_health_records(health_records)
# Out:
# ----------------------------------------------------------------------------------------------------
# Patient:
#  - ID: 4440ff11-69ec-440b-a2bd-dc1c14105e8e
#  - BIRTHDATE: 2001-11-20
#  - MARITAL:
#  - RACE: white
#  - ETHNICITY: hispanic
#  - GENDER: F
# ----------------------------------------------------------------------------------------------------
# Allergies:
#  - Allergy to mould
#  - House dust mite allergy
#  - Dander (animal) allergy
#  - Allergy to grass pollen
#  - Allergy to tree pollen
#  - Allergy to eggs
#  - Allergy to wheat
#  - Allergy to peanuts
# ----------------------------------------------------------------------------------------------------
# Careplans:
#  - Self-care interventions (procedure)
#  - Skin condition care
#  - Allergic disorder monitoring
# ----------------------------------------------------------------------------------------------------
# Conditions:
#  - Atopic dermatitis
#  - Perennial allergic rhinitis
#  - Acute viral pharyngitis (disorder)
#  - Acute allergic reaction
# ----------------------------------------------------------------------------------------------------
# Devices:
# ----------------------------------------------------------------------------------------------------
# Encounters:
#  - Encounter for problem
#  - Encounter for problem
#  - Encounter for problem
#  - Encounter for symptom
#  - Well child visit (procedure)
#  - Well child visit (procedure)
#  - Well child visit (procedure)
#  - Encounter for symptom
#  - Well child visit (procedure)
#  - Emergency room admission (procedure)
#  - Encounter for problem
#  - Allergic disorder initial assessment
#  - Well child visit (procedure)
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Consultation for treatment
#  - Outpatient procedure
#  - Outpatient procedure
#  - Well child visit (procedure)
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Well child visit (procedure)
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Consultation for treatment
#  - Outpatient procedure
#  - Outpatient procedure
#  - Well child visit (procedure)
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Outpatient procedure
#  - Allergic disorder follow-up assessment
#  - Well child visit (procedure)
#  - Consultation for treatment
#  - General examination of patient (procedure)
# ----------------------------------------------------------------------------------------------------
# Imagings:
# ----------------------------------------------------------------------------------------------------
# Immunizations:
#  - Influenza  seasonal  injectable  preservative free
#  - Influenza  seasonal  injectable  preservative free
#  - Tdap
#  - Influenza  seasonal  injectable  preservative free
#  - HPV  quadrivalent
#  - meningococcal MCV4P
#  - Influenza  seasonal  injectable  preservative free
#  - HPV  quadrivalent
#  - Influenza  seasonal  injectable  preservative free
#  - HPV  quadrivalent
#  - Influenza  seasonal  injectable  preservative free
#  - Influenza  seasonal  injectable  preservative free
#  - Influenza  seasonal  injectable  preservative free
#  - meningococcal MCV4P
#  - Influenza  seasonal  injectable  preservative free
#  - Influenza  seasonal  injectable  preservative free
# ----------------------------------------------------------------------------------------------------
# Medications:
#  - Loratadine 5 MG Chewable Tablet
#  - NDA020800 0.3 ML Epinephrine 1 MG/ML Auto-Injector
#  - predniSONE 5 MG Oral Tablet
#  - Levora 0.15/30 28 Day Pack
#  - Levora 0.15/30 28 Day Pack
#  - Yaz 28 Day Pack
# ----------------------------------------------------------------------------------------------------
# Observations:
#  - Body Height: 134.7 cm
#  - Pain severity - 0-10 verbal numeric rating [Score] - Reported: 3.0 {score}
#  - Body Weight: 32.6 kg
#  - Body Mass Index: 18.0 kg/m2
#  - Body mass index (BMI) [Percentile] Per age and gender: 75.1 %
#  - Diastolic Blood Pressure: 79.0 mm[Hg]
#  - Systolic Blood Pressure: 117.0 mm[Hg]
#  - Heart rate: 61.0 /min
#  - Respiratory rate: 15.0 /min
#  - Tobacco smoking status NHIS: Never smoker
#  - Body Height: 139.9 cm
#  - Pain severity - 0-10 verbal numeric rating [Score] - Reported: 3.0 {score}
#  - Body Weight: 35.3 kg
#  - Body Mass Index: 18.0 kg/m2
#  - Body mass index (BMI) [Percentile] Per age and gender: 67.6 %
#  - Diastolic Blood Pressure: 83.0 mm[Hg]
#  - Systolic Blood Pressure: 104.0 mm[Hg]
#  - Heart rate: 92.0 /min
#  - Respiratory rate: 12.0 /min
#  - Tobacco smoking status NHIS: Never smoker
#  - Body Height: 146.1 cm
#  - Pain severity - 0-10 verbal numeric rating [Score] - Reported: 2.0 {score}
#  - Body Weight: 39.6 kg
#  - Body Mass Index: 18.6 kg/m2
#  - Body mass index (BMI) [Percentile] Per age and gender: 65.3 %
#  - Diastolic Blood Pressure: 78.0 mm[Hg]
#  - Systolic Blood Pressure: 107.0 mm[Hg]
#  - Heart rate: 91.0 /min
#  - Respiratory rate: 13.0 /min
#  - Leukocytes [#/volume] in Blood by Automated count: 10.3 10*3/uL
#  - Erythrocytes [#/volume] in Blood by Automated count: 4.7 10*6/uL
#  - Hemoglobin [Mass/volume] in Blood: 12.2 g/dL
#  - Hematocrit [Volume Fraction] of Blood by Automated count: 47.4 %
#  - MCV [Entitic volume] by Automated count: 94.9 fL
#  - MCH [Entitic mass] by Automated count: 32.7 pg
#  - MCHC [Mass/volume] by Automated count: 34.8 g/dL
#  - Erythrocyte distribution width [Entitic volume] by Automated count: 43.9 fL
#  - Platelets [#/volume] in Blood by Automated count: 369.1 10*3/uL
#  - Platelet distribution width [Entitic volume] in Blood by Automated count: 307.4 fL
#  - Platelet mean volume [Entitic volume] in Blood by Automated count: 10.6 fL
#  - Tobacco smoking status NHIS: Never smoker
#  - Body temperature: 37.5 Cel
#  - Body Height: 153.3 cm
#  - Pain severity - 0-10 verbal numeric rating [Score] - Reported: 2.0 {score}
#  - Body Weight: 49.7 kg
#  - Body Mass Index: 21.2 kg/m2
#  - Body mass index (BMI) [Percentile] Per age and gender: 81.7 %
#  - Diastolic Blood Pressure: 77.0 mm[Hg]
#  - Systolic Blood Pressure: 107.0 mm[Hg]
#  - Heart rate: 63.0 /min
#  - Respiratory rate: 14.0 /min
#  - Tobacco smoking status NHIS: Never smoker
#  - Peanut IgE Ab in Serum: 81.6 kU/L
#  - Walnut IgE Ab in Serum: 0.3 kU/L
#  - Codfish IgE Ab in Serum: 0.1 kU/L
#  - Shrimp IgE Ab in Serum: 0.0 kU/L
#  - Wheat IgE Ab in Serum: 44.7 kU/L
#  - Egg white IgE Ab in Serum: 8.8 kU/L
#  - Soybean IgE Ab in Serum: 0.1 kU/L
#  - Cow milk IgE Ab in Serum: 0.2 kU/L
#  - White oak IgE Ab in Serum: 9.1 kU/L
#  - Common Ragweed IgE Ab in Serum: 57.2 kU/L
#  - Cat dander IgE Ab in Serum: 81.5 kU/L
#  - American house dust mite IgE Ab in Serum: 69.1 kU/L
#  - Cladosporium herbarum IgE Ab in Serum: 2.9 kU/L
#  - Honey bee IgE Ab in Serum: 0.1 kU/L
#  - Latex IgE Ab in Serum: 0.2 kU/L
#  - Body Height: 159.1 cm
#  - Pain severity - 0-10 verbal numeric rating [Score] - Reported: 2.0 {score}
#  - Body Weight: 59.0 kg
#  - Body Mass Index: 23.3 kg/m2
#  - Body mass index (BMI) [Percentile] Per age and gender: 88.1 %
#  - Diastolic Blood Pressure: 83.0 mm[Hg]
#  - Systolic Blood Pressure: 118.0 mm[Hg]
#  - Heart rate: 72.0 /min
#  - Respiratory rate: 15.0 /min
#  - Tobacco smoking status NHIS: Never smoker
#  - Body Height: 162.3 cm
#  - Pain severity - 0-10 verbal numeric rating [Score] - Reported: 4.0 {score}
#  - Body Weight: 60.5 kg
#  - Body Mass Index: 23.0 kg/m2
#  - Body mass index (BMI) [Percentile] Per age and gender: 82.8 %
#  - Diastolic Blood Pressure: 75.0 mm[Hg]
#  - Systolic Blood Pressure: 128.0 mm[Hg]
#  - Heart rate: 80.0 /min
#  - Respiratory rate: 16.0 /min
#  - Tobacco smoking status NHIS: Never smoker
#  - Body Height: 163.6 cm
#  - Pain severity - 0-10 verbal numeric rating [Score] - Reported: 3.0 {score}
#  - Body Weight: 60.8 kg
#  - Body Mass Index: 22.7 kg/m2
#  - Body mass index (BMI) [Percentile] Per age and gender: 77.5 %
#  - Diastolic Blood Pressure: 82.0 mm[Hg]
#  - Systolic Blood Pressure: 116.0 mm[Hg]
#  - Heart rate: 67.0 /min
#  - Respiratory rate: 14.0 /min
#  - Tobacco smoking status NHIS: Never smoker
#  - Body Height: 164.2 cm
#  - Pain severity - 0-10 verbal numeric rating [Score] - Reported: 1.0 {score}
#  - Body Weight: 61.8 kg
#  - Body Mass Index: 22.9 kg/m2
#  - Body mass index (BMI) [Percentile] Per age and gender: 74.8 %
#  - Diastolic Blood Pressure: 80.0 mm[Hg]
#  - Systolic Blood Pressure: 131.0 mm[Hg]
#  - Heart rate: 71.0 /min
#  - Respiratory rate: 16.0 /min
#  - Leukocytes [#/volume] in Blood by Automated count: 8.0 10*3/uL
#  - Erythrocytes [#/volume] in Blood by Automated count: 3.9 10*6/uL
#  - Hemoglobin [Mass/volume] in Blood: 16.8 g/dL
#  - Hematocrit [Volume Fraction] of Blood by Automated count: 36.5 %
#  - MCV [Entitic volume] by Automated count: 85.7 fL
#  - MCH [Entitic mass] by Automated count: 27.5 pg
#  - MCHC [Mass/volume] by Automated count: 34.3 g/dL
#  - Erythrocyte distribution width [Entitic volume] by Automated count: 40.7 fL
#  - Platelets [#/volume] in Blood by Automated count: 265.4 10*3/uL
#  - Platelet distribution width [Entitic volume] in Blood by Automated count: 503.2 fL
#  - Platelet mean volume [Entitic volume] in Blood by Automated count: 9.9 fL
#  - Tobacco smoking status NHIS: Never smoker
#  - Peanut IgE Ab in Serum: 9.0 kU/L
#  - Walnut IgE Ab in Serum: 0.3 kU/L
#  - Codfish IgE Ab in Serum: 0.3 kU/L
#  - Shrimp IgE Ab in Serum: 0.2 kU/L
#  - Wheat IgE Ab in Serum: 23.1 kU/L
#  - Egg white IgE Ab in Serum: 27.5 kU/L
#  - Soybean IgE Ab in Serum: 0.2 kU/L
#  - Cow milk IgE Ab in Serum: 0.1 kU/L
#  - White oak IgE Ab in Serum: 50.4 kU/L
#  - Common Ragweed IgE Ab in Serum: 89.6 kU/L
#  - Cat dander IgE Ab in Serum: 49.9 kU/L
#  - American house dust mite IgE Ab in Serum: 77.7 kU/L
#  - Cladosporium herbarum IgE Ab in Serum: 36.2 kU/L
#  - Honey bee IgE Ab in Serum: 0.3 kU/L
#  - Latex IgE Ab in Serum: 0.2 kU/L
#  - Body Height: 164.6 cm
#  - Pain severity - 0-10 verbal numeric rating [Score] - Reported: 2.0 {score}
#  - Body Weight: 66.8 kg
#  - Body Mass Index: 24.6 kg/m2
#  - Body mass index (BMI) [Percentile] Per age and gender: 82.3 %
#  - Diastolic Blood Pressure: 85.0 mm[Hg]
#  - Systolic Blood Pressure: 126.0 mm[Hg]
#  - Heart rate: 87.0 /min
#  - Respiratory rate: 14.0 /min
#  - Tobacco smoking status NHIS: Never smoker
#  - Body Height: 164.8 cm
#  - Pain severity - 0-10 verbal numeric rating [Score] - Reported: 1.0 {score}
#  - Body Weight: 68.4 kg
#  - Body Mass Index: 25.2 kg/m2
#  - Body mass index (BMI) [Percentile] Per age and gender: 82.7 %
#  - Diastolic Blood Pressure: 85.0 mm[Hg]
#  - Systolic Blood Pressure: 103.0 mm[Hg]
#  - Heart rate: 91.0 /min
#  - Respiratory rate: 13.0 /min
#  - Tobacco smoking status NHIS: Never smoker
#  - QALY: 7.8 a
#  - QALY: 8.8 a
#  - QALY: 9.8 a
#  - QALY: 10.7 a
#  - QALY: 11.7 a
#  - QALY: 12.7 a
#  - QALY: 13.6 a
#  - QALY: 14.6 a
#  - QALY: 15.5 a
#  - QALY: 16.5 a
#  - DALY: 0.2 a
#  - DALY: 0.2 a
#  - DALY: 0.2 a
#  - DALY: 0.3 a
#  - DALY: 0.3 a
#  - DALY: 0.3 a
#  - DALY: 0.4 a
#  - DALY: 0.4 a
#  - DALY: 0.5 a
#  - DALY: 0.5 a
#  - QOLS: 1.0 {score}
#  - QOLS: 1.0 {score}
#  - QOLS: 1.0 {score}
#  - QOLS: 1.0 {score}
#  - QOLS: 1.0 {score}
#  - QOLS: 1.0 {score}
#  - QOLS: 1.0 {score}
#  - QOLS: 1.0 {score}
#  - QOLS: 1.0 {score}
#  - QOLS: 1.0 {score}
# ----------------------------------------------------------------------------------------------------
# Procedures:
#  - Medication Reconciliation (procedure)
#  - Throat culture (procedure)
#  - Injection of adrenaline
#  - Allergy screening test
#  - Medication Reconciliation (procedure)
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Medication Reconciliation (procedure)
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Medication Reconciliation (procedure)
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Subcutaneous immunotherapy
#  - Allergy screening test
#  - Medication Reconciliation (procedure)
# ----------------------------------------------------------------------------------------------------
